# %% [markdown]
# This is my test notebook which help me figure out some coding related issues before updating the .py files.

# %%
import pandas as pd
import numpy as np
import plotly.express as px
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('./data/sample.csv')
df.head(25)
# Out:
#    created_date        borough channel    complaint_type  response_time_days
# 0    2024-02-02         Queens     Web          Plumbing               18.27
# 1    2024-10-09      Manhattan   Phone          Plumbing                3.52
# 2    2024-08-26         Queens   Phone           Rodents                2.34
# 3    2024-06-09       Brooklyn     Web           Rodents                2.08
# 4    2024-06-07          Bronx     App          Plumbing                5.95
# 5    2024-11-09       Brooklyn     Web  Street Condition                9.78
# 6    2024-02-01       Brooklyn     Web   Illegal Parking               27.82
# 7    2024-09-11         Queens   Phone  Street Condition                3.56
# 8    2024-03-14       Brooklyn   Phone   Illegal Parking                5.72
# 9    2024-02-04      Manhattan   Phone          Plumbing                9.96
# 10   2024-07-11       Brooklyn     Web  Street Condition                6.76
# ...

# %%
df['complaint_type'].value_counts().index.tolist()[0]
# Out:
# 'Heat/Hot Water'

# %%
df['response_time_days'].median()
# Out:
# np.float64(5.005000000000001)

# %%
len(df)
# Out:
# 600

# %%
df.groupby("borough", as_index=False)["response_time_days"].median().rename(columns={"response_time_days": "median_response_days"}).sort_values("median_response_days", ascending=False)
# Out:
#          borough  median_response_days
# 0          Bronx                 6.770
# 1       Brooklyn                 6.370
# 3         Queens                 4.770
# 4  Staten Island                 4.735
# 2      Manhattan                 3.420

# %%
df_2 = df['borough'].value_counts().reset_index()
#data.columns
df_2.head()
fig = px.bar(df_2, x='borough', y='count')
fig.show()
